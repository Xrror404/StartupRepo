# %% [markdown]
# # Installation Requirement

# %%
# !pip install tensorflow scikit-learn pandas numpy pickle5 wget psutil polars
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255314 sha256=64c9a701a3689db2f75d675a79e22972ef114960dad0d5e45673144a1a882fb7
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=3a594f63977650c3b0160af8134f1b6c471890d95950d3792a21653be2d5be64
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built pickle5 wget
# ...

# %%
import psutil
psutil.virtual_memory()
# Out:
# svmem(total=13609431040, available=12405702656, percent=8.8, used=868986880, free=7585402880, active=699924480, inactive=4984057856, buffers=390459392, cached=4764581888, shared=1654784, slab=235601920)

# %%
# Install wget if not already installed
# !pip install wget

import wget
import gzip
import shutil
import os
import ssl

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context

# URL of the dataset
url = 'https://jmcauley.ucsd.edu/data/amazon_v2/categoryFilesSmall/Gift_Cards_5.json.gz'


print(f"Downloading dataset from {url} to {filepath}...")

# Download the file using wget with progress bar
wget.download(url, filepath, bar=wget.bar_thermometer)

# Verify if the file has been downloaded successfully
if os.path.exists(filepath):
    print(f"\nDataset downloaded successfully at {filepath}")
else:
    print("\nDownload failed.")
# Out:
# ...
# []
# Dataset downloaded successfully at /content/Gift_Cards_5.json.gz

# %%
import pandas as pd

# File path where you want to save the dataset
filepath = '/content/Gift_Cards_5.json.gz'
df = pd.read_json(filepath,lines=True)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0           5      True  06 17, 2018  A31UBHTUUIFJUT  B004LLIKVU
# 1           4      True  06 14, 2018  A2MN5JQMIY0FQ2  B004LLIKVU
# 2           5      True   06 2, 2018  A25POI5IGGENPM  B004LLIKVU
# 3           5      True  05 19, 2018  A2HYGTHB4LJ9FW  B004LLIKVU
# 4           5      True  05 18, 2018   ACDG3M94UMZGJ  B004LLIKVU
# ...       ...       ...          ...             ...         ...
# 2967        5      True  07 10, 2018  A1MXZ1CW0ZVTKL  B01DWOZKSC
# 2968        4      True  06 19, 2018  A1SVYJFIASQ46Z  B01DWOZKSC
# 2969        5      True   06 8, 2018  A1QZ08NSDCZBA3  B01E4QS95I
# 2970        5      True  11 10, 2017  A1L4GG3FBMIG6V  B01FERR9FW
# 2971        5      True  07 10, 2018  A1MXZ1CW0ZVTKL  B01GKWEPBG
#
#                          style      reviewerName  \
# 0      {'Gift Amount:': ' 50'}      john stoiber
# 1      {'Gift Amount:': ' 50'}   Amazon Customer
# ...

# %%
df
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0           5      True  06 17, 2018  A31UBHTUUIFJUT  B004LLIKVU
# 1           4      True  06 14, 2018  A2MN5JQMIY0FQ2  B004LLIKVU
# 2           5      True   06 2, 2018  A25POI5IGGENPM  B004LLIKVU
# 3           5      True  05 19, 2018  A2HYGTHB4LJ9FW  B004LLIKVU
# 4           5      True  05 18, 2018   ACDG3M94UMZGJ  B004LLIKVU
# ...       ...       ...          ...             ...         ...
# 2967        5      True  07 10, 2018  A1MXZ1CW0ZVTKL  B01DWOZKSC
# 2968        4      True  06 19, 2018  A1SVYJFIASQ46Z  B01DWOZKSC
# 2969        5      True   06 8, 2018  A1QZ08NSDCZBA3  B01E4QS95I
# 2970        5      True  11 10, 2017  A1L4GG3FBMIG6V  B01FERR9FW
# 2971        5      True  07 10, 2018  A1MXZ1CW0ZVTKL  B01GKWEPBG
#
#                          style      reviewerName  \
# 0      {'Gift Amount:': ' 50'}      john stoiber
# 1      {'Gift Amount:': ' 50'}   Amazon Customer
# ...

# %%
# prompt: Using dataframe df: i want to make sentiment analysis

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Preprocess the data
df['reviewText'] = df['reviewText'].str.lower()
df['reviewText'] = df['reviewText'].str.replace('[^\w\s]', '')

# Create a bag-of-words model
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['reviewText'])

# Create a logistic regression model
model = LogisticRegression()

# Split

# %%
import pandas as pd
from textblob import TextBlob

# Assuming 'df' is your DataFrame containing the data
# Fill missing reviewText values with an empty string
df['reviewText'] = df['reviewText'].fillna('')

# Perform sentiment analysis on each reviewText
# def get_sentiment(text):
#     analysis = TextBlob(text)
#     return analysis.sentiment.polarity  # Polarity ranges from -1 (negative) to 1 (positive)

word_polarity = {
    "good": 0.5,
    "bad": -0.5,
    # Add more words and their scores
}
def get_sentiment(text):
    total_score = 0.0

    # Tokenize the text (split by spaces)
    # Preprocess each word (remove punctuation, convert to lowercase, etc.)
    # Calculate the sentiment score for each word
    # Accumulate the scores
    # You can use a more sophisticated approach with a larger lexicon

    # For simplicity, let's assume the input text contains only one word
    if text in word_polarity:
        total_score += word_polarity[text]

    return total_score


df['sentiment'] = df['reviewText'].apply(get_sentiment)

# Categorize sentiments (optional)
df['sentiment_category'] = df['sentiment'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

# Now your DataFrame contains sentiment scores and categories
print(df[['reviewText', 'sentiment', 'sentiment_category']])
# Out:
#                                             reviewText  sentiment  \
# 0                                  Another great gift.   0.800000
# 1                            Gift card for my daughter   0.000000
# 2                                         Nice present   0.300000
# 3     My niece loved this birthday greeting/gift card.   0.700000
# 4                                      fine as a gift.   0.416667
# ...                                                ...        ...
# 2967    Not much to say, gift card is as good as cash!   0.387500
# 2968                                    Nice gift card   0.600000
# 2969                                              Gift   0.000000
# 2970                                      Pretty good!   0.562500
# 2971    Not much to say, gift card is as good as cash!   0.387500
#
#      sentiment_category
# 0              Positive
# 1               Neutral
# 2              Positive
# 3              Positive
# 4              Positive
# ...

# %%
# let a = ""
# for(let i = 1; i < 65536; i++) {
#     a += i+", ";
# }
# console.log(a)
